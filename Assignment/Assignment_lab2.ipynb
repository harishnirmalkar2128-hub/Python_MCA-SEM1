# %%
# Program to find the probability of rolling a number on a dice

total_outcomes = 6    # Numbers on a dice : 1 to 6
desired_outcomes = 1  # Probability of getting ONE specific number

probability = desired_outcomes / total_outcomes

print("Probability of rolling any specific number on a dice is:", probability)
# Out:
# Probability of rolling any specific number on a dice is: 0.16666666666666666
